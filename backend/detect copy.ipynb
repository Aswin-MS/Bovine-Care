# %%
import cv2
from ultralytics import YOLO
import torch
import torch.nn as nn
from torchvision import transforms, models
from PIL import Image

# %%
# Load YOLO models
model_cow = YOLO('cowModel.pt')

# %%
# Open video file
video_path = 'cowvideo.mp4'  # Replace with your video path
cap = cv2.VideoCapture(video_path)

# %%
# Define transformations (same as used during training)
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load MobileNetV2 model
model = models.mobilenet_v2(weights=None)
model.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(model.last_channel, 2)
)

# Load trained model weights
MODEL_PATH = "D:\\aswin\\Study\\Class\\s8\\bc\\backend\\best_model_epoch16_f10.926.pth"
checkpoint = torch.load(MODEL_PATH, map_location=torch.device('cpu'))

# Load state dict into the model
if isinstance(checkpoint, dict) and 'state_dict' in checkpoint:
    model.load_state_dict(checkpoint['state_dict'], strict=True)
else:
    model.load_state_dict(checkpoint, strict=True)

model.eval()

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
def predict(image_input):
    # Check if the input is a PIL.Image object
    if isinstance(image_input, Image.Image):
        image = image_input.convert('RGB')  # Ensure image is in RGB format
    else:
        # Assume it's a file path
        image = Image.open(image_input).convert('RGB')

    # Preprocess the image
    image = transform(image).unsqueeze(0)  # Add batch dimension
    image = image.to(device)  # Move image to the same device as the model

    # Perform prediction
    with torch.no_grad():
        outputs = model(image)
        _, predicted = outputs.max(1)

    return predicted.item() == 0  # Return True if the image has lumps

# %%
# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
if fps <= 0:  # Handle invalid FPS values
    fps = 30

# Initialize video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_video.mp4', fourcc, fps, (frame_width, frame_height))

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Detect cows (using YOLO or your detection model)
    results_cow = model_cow.predict(frame)
    
    if len(results_cow) > 0 and hasattr(results_cow[0], "boxes"):
        cow_boxes = results_cow[0].boxes.data.cpu().numpy()
    else:
        cow_boxes = []

    for box in cow_boxes:
        x1, y1, x2, y2, conf, cls = box.astype(int)
        cow_region = frame[y1:y2, x1:x2]

        # Convert OpenCV BGR to PIL RGB
        cow_region_pil = Image.fromarray(cv2.cvtColor(cow_region, cv2.COLOR_BGR2RGB))

        # Detect lumps using MobileNet (now works with PIL Image)
        has_lumps = predict(cow_region_pil)  # Directly pass the PIL Image

        # Draw bounding box
        color = (0, 0, 255) if has_lumps else (0, 255, 0)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        label = "Infected" if has_lumps else "Healthy"
        cv2.putText(frame, f'Cow {conf:.2f} - {label}', (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Write the processed frame to output video
    out.write(frame)

    # Show frame
    cv2.imshow('Detection', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 2 cows, 200.1ms
# Speed: 11.5ms preprocess, 200.1ms inference, 13.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 87.9ms
# Speed: 4.5ms preprocess, 87.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 86.6ms
# Speed: 2.0ms preprocess, 86.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 88.0ms
# Speed: 4.3ms preprocess, 88.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cows, 86.2ms
# Speed: 2.3ms preprocess, 86.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cows, 81.8ms
# Speed: 1.8ms preprocess, 81.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cows, 79.2ms
# Speed: 1.7ms preprocess, 79.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cows, 75.9ms
# Speed: 1.7ms preprocess, 75.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cows, 79.9ms
# Speed: 2.4ms preprocess, 79.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cows, 82.1ms
# Speed: 1.9ms preprocess, 82.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 83.0ms
# Speed: 1.7ms preprocess, 83.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 120.3ms
# Speed: 1.7ms preprocess, 120.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 80.4ms
# Speed: 1.3ms preprocess, 80.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 79.9ms
# Speed: 1.8ms preprocess, 79.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 76.8ms
# Speed: 1.9ms preprocess, 76.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 80.4ms
# Speed: 2.0ms preprocess, 80.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 79.2ms
# Speed: 1.4ms preprocess, 79.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 79.3ms
# Speed: 1.7ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 79.8ms
# Speed: 1.6ms preprocess, 79.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 80.1ms
# Speed: 1.5ms preprocess, 80.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.1ms
# Speed: 2.1ms preprocess, 78.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 79.6ms
# Speed: 1.8ms preprocess, 79.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 90.3ms
# Speed: 2.3ms preprocess, 90.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 95.2ms
# Speed: 3.1ms preprocess, 95.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.0ms
# Speed: 1.9ms preprocess, 79.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.6ms
# Speed: 1.8ms preprocess, 80.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.7ms
# Speed: 1.3ms preprocess, 79.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.9ms
# Speed: 1.8ms preprocess, 79.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 92.4ms
# Speed: 2.3ms preprocess, 92.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 92.0ms
# Speed: 1.9ms preprocess, 92.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.4ms
# Speed: 1.9ms preprocess, 81.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.8ms
# Speed: 1.9ms preprocess, 78.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.3ms
# Speed: 2.1ms preprocess, 80.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 2.5ms preprocess, 79.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.9ms
# Speed: 2.1ms preprocess, 77.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.9ms
# Speed: 1.9ms preprocess, 76.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.6ms
# Speed: 1.7ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 122.9ms
# Speed: 1.9ms preprocess, 122.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.1ms
# Speed: 1.7ms preprocess, 81.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.4ms
# Speed: 2.3ms preprocess, 77.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.4ms
# Speed: 1.8ms preprocess, 78.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.4ms
# Speed: 1.8ms preprocess, 78.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.7ms
# Speed: 1.5ms preprocess, 77.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.6ms
# Speed: 2.1ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.2ms
# Speed: 1.5ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 79.2ms
# Speed: 1.7ms preprocess, 79.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.3ms
# Speed: 1.6ms preprocess, 78.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.6ms
# Speed: 1.5ms preprocess, 76.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.0ms
# Speed: 2.1ms preprocess, 78.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.6ms
# Speed: 1.5ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.0ms
# Speed: 1.7ms preprocess, 79.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 93.2ms
# Speed: 3.0ms preprocess, 93.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 93.0ms
# Speed: 2.5ms preprocess, 93.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 1.7ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.2ms
# Speed: 1.9ms preprocess, 79.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 1.7ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cows, 74.4ms
# Speed: 1.8ms preprocess, 74.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.9ms
# Speed: 2.1ms preprocess, 79.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 126.3ms
# Speed: 2.2ms preprocess, 126.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.4ms
# Speed: 1.5ms preprocess, 78.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.6ms
# Speed: 1.7ms preprocess, 78.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 79.3ms
# Speed: 1.7ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.2ms
# Speed: 2.3ms preprocess, 76.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.1ms
# Speed: 1.7ms preprocess, 74.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.5ms
# Speed: 1.7ms preprocess, 79.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 81.6ms
# Speed: 2.0ms preprocess, 81.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 76.2ms
# Speed: 1.8ms preprocess, 76.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.1ms
# Speed: 1.9ms preprocess, 78.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.3ms
# Speed: 1.8ms preprocess, 80.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.4ms
# Speed: 1.8ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.6ms
# Speed: 1.8ms preprocess, 75.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.2ms
# Speed: 2.1ms preprocess, 74.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.0ms
# Speed: 1.8ms preprocess, 80.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 1.6ms preprocess, 79.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.0ms
# Speed: 1.5ms preprocess, 74.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.2ms
# Speed: 1.5ms preprocess, 74.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.9ms
# Speed: 2.1ms preprocess, 80.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.3ms
# Speed: 1.7ms preprocess, 78.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.8ms
# Speed: 1.7ms preprocess, 75.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.9ms
# Speed: 1.9ms preprocess, 77.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.4ms
# Speed: 1.8ms preprocess, 76.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.1ms
# Speed: 1.7ms preprocess, 80.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.0ms
# Speed: 1.7ms preprocess, 79.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.3ms
# Speed: 2.1ms preprocess, 74.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.5ms
# Speed: 2.3ms preprocess, 75.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.4ms
# Speed: 1.8ms preprocess, 79.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.4ms
# Speed: 1.8ms preprocess, 80.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.7ms
# Speed: 2.1ms preprocess, 80.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.8ms
# Speed: 1.7ms preprocess, 76.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.2ms
# Speed: 2.7ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 2.1ms preprocess, 79.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 73.6ms
# Speed: 1.7ms preprocess, 73.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.5ms
# Speed: 1.7ms preprocess, 76.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.8ms
# Speed: 2.3ms preprocess, 77.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.4ms
# Speed: 1.5ms preprocess, 79.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.7ms
# Speed: 2.3ms preprocess, 78.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 1.9ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.8ms
# Speed: 1.8ms preprocess, 79.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.1ms
# Speed: 1.9ms preprocess, 77.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 73.8ms
# Speed: 2.1ms preprocess, 73.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.6ms
# Speed: 1.5ms preprocess, 80.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 1.9ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.6ms
# Speed: 3.3ms preprocess, 77.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.8ms
# Speed: 1.8ms preprocess, 77.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.7ms
# Speed: 2.2ms preprocess, 80.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.9ms
# Speed: 2.7ms preprocess, 81.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.6ms
# Speed: 2.1ms preprocess, 74.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.3ms
# Speed: 2.3ms preprocess, 78.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.0ms
# Speed: 1.7ms preprocess, 75.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.1ms
# Speed: 1.7ms preprocess, 78.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 2.0ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.3ms
# Speed: 1.6ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.9ms
# Speed: 1.8ms preprocess, 78.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.0ms
# Speed: 1.7ms preprocess, 80.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.7ms
# Speed: 1.9ms preprocess, 78.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.1ms
# Speed: 1.7ms preprocess, 81.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.1ms
# Speed: 1.7ms preprocess, 78.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.8ms
# Speed: 1.8ms preprocess, 78.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.1ms
# Speed: 2.3ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.8ms
# Speed: 2.3ms preprocess, 78.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.2ms
# Speed: 2.0ms preprocess, 80.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.6ms
# Speed: 2.2ms preprocess, 80.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.0ms
# Speed: 2.3ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.8ms
# Speed: 1.7ms preprocess, 78.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.8ms
# Speed: 2.5ms preprocess, 79.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.8ms
# Speed: 1.9ms preprocess, 77.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.0ms
# Speed: 1.8ms preprocess, 78.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 88.2ms
# Speed: 2.3ms preprocess, 88.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.9ms
# Speed: 2.4ms preprocess, 80.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.2ms
# Speed: 2.2ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.6ms
# Speed: 1.7ms preprocess, 74.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.3ms
# Speed: 1.9ms preprocess, 81.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.1ms
# Speed: 2.3ms preprocess, 80.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.6ms
# Speed: 2.1ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.9ms
# Speed: 1.9ms preprocess, 77.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.2ms
# Speed: 1.7ms preprocess, 77.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.7ms
# Speed: 1.8ms preprocess, 77.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.7ms
# Speed: 2.2ms preprocess, 78.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.1ms
# Speed: 1.9ms preprocess, 78.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 2.0ms preprocess, 79.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 82.0ms
# Speed: 2.4ms preprocess, 82.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.9ms
# Speed: 1.7ms preprocess, 78.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 1.8ms preprocess, 79.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.2ms
# Speed: 1.9ms preprocess, 76.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 1.6ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.8ms
# Speed: 1.8ms preprocess, 78.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.1ms
# Speed: 1.7ms preprocess, 74.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 2.5ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.4ms
# Speed: 2.1ms preprocess, 81.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.9ms
# Speed: 1.7ms preprocess, 79.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 2.2ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.6ms
# Speed: 1.8ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 82.5ms
# Speed: 2.0ms preprocess, 82.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.4ms
# Speed: 2.1ms preprocess, 79.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.3ms
# Speed: 2.2ms preprocess, 76.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.8ms
# Speed: 1.7ms preprocess, 79.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.2ms
# Speed: 1.9ms preprocess, 79.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.6ms
# Speed: 1.9ms preprocess, 76.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.7ms
# Speed: 1.7ms preprocess, 77.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 1.8ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.2ms
# Speed: 2.1ms preprocess, 76.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 71.3ms
# Speed: 1.9ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 81.4ms
# Speed: 2.1ms preprocess, 81.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.0ms
# Speed: 1.6ms preprocess, 81.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 80.7ms
# Speed: 1.5ms preprocess, 80.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.7ms
# Speed: 2.3ms preprocess, 78.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 94.3ms
# Speed: 4.0ms preprocess, 94.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.2ms
# Speed: 1.7ms preprocess, 77.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 1.5ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 1.8ms preprocess, 79.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 1.8ms preprocess, 79.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.2ms
# Speed: 1.9ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 80.2ms
# Speed: 1.8ms preprocess, 80.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 72.3ms
# Speed: 1.7ms preprocess, 72.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.1ms
# Speed: 2.1ms preprocess, 77.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.8ms
# Speed: 1.8ms preprocess, 76.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.1ms
# Speed: 1.8ms preprocess, 78.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.5ms
# Speed: 1.7ms preprocess, 77.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.7ms
# Speed: 2.2ms preprocess, 79.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.3ms
# Speed: 1.9ms preprocess, 80.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.4ms
# Speed: 1.9ms preprocess, 78.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.0ms
# Speed: 1.8ms preprocess, 78.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.6ms
# Speed: 2.2ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.2ms
# Speed: 1.9ms preprocess, 75.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.4ms
# Speed: 2.4ms preprocess, 80.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.6ms
# Speed: 2.8ms preprocess, 77.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.3ms
# Speed: 1.8ms preprocess, 80.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.5ms
# Speed: 2.4ms preprocess, 76.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.1ms
# Speed: 1.7ms preprocess, 78.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 2.0ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.7ms
# Speed: 1.9ms preprocess, 80.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.7ms
# Speed: 1.9ms preprocess, 75.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 81.0ms
# Speed: 1.8ms preprocess, 81.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.9ms
# Speed: 2.4ms preprocess, 76.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.0ms
# Speed: 1.5ms preprocess, 77.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.9ms
# Speed: 2.5ms preprocess, 78.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.1ms
# Speed: 1.7ms preprocess, 78.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.1ms
# Speed: 1.6ms preprocess, 75.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.3ms
# Speed: 1.8ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 73.2ms
# Speed: 2.3ms preprocess, 73.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.9ms
# Speed: 1.9ms preprocess, 77.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.2ms
# Speed: 1.9ms preprocess, 76.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 1.7ms preprocess, 79.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.1ms
# Speed: 1.9ms preprocess, 78.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 74.6ms
# Speed: 1.8ms preprocess, 74.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 71.8ms
# Speed: 2.3ms preprocess, 71.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.3ms
# Speed: 1.6ms preprocess, 78.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 80.4ms
# Speed: 2.2ms preprocess, 80.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 75.1ms
# Speed: 1.7ms preprocess, 75.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.4ms
# Speed: 1.3ms preprocess, 79.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.8ms
# Speed: 1.8ms preprocess, 77.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.8ms
# Speed: 1.6ms preprocess, 75.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.1ms
# Speed: 1.7ms preprocess, 79.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.4ms
# Speed: 2.0ms preprocess, 80.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.1ms
# Speed: 1.7ms preprocess, 77.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 74.4ms
# Speed: 1.6ms preprocess, 74.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.1ms
# Speed: 1.7ms preprocess, 75.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 77.1ms
# Speed: 1.5ms preprocess, 77.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.5ms
# Speed: 1.8ms preprocess, 78.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.6ms
# Speed: 1.5ms preprocess, 77.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.5ms
# Speed: 1.6ms preprocess, 78.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.2ms
# Speed: 1.7ms preprocess, 75.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 71.5ms
# Speed: 1.8ms preprocess, 71.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.0ms
# Speed: 2.2ms preprocess, 78.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 75.3ms
# Speed: 1.4ms preprocess, 75.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 77.8ms
# Speed: 1.7ms preprocess, 77.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 74.3ms
# Speed: 1.8ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 74.5ms
# Speed: 2.2ms preprocess, 74.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.0ms
# Speed: 2.3ms preprocess, 79.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.5ms
# Speed: 1.8ms preprocess, 77.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.1ms
# Speed: 1.7ms preprocess, 80.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 79.1ms
# Speed: 1.5ms preprocess, 79.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 75.2ms
# Speed: 1.6ms preprocess, 75.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cows, 78.3ms
# Speed: 1.9ms preprocess, 78.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.5ms
# Speed: 1.7ms preprocess, 77.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.3ms
# Speed: 1.7ms preprocess, 78.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.2ms
# Speed: 1.6ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 2.3ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.7ms
# Speed: 1.9ms preprocess, 78.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.0ms
# Speed: 1.7ms preprocess, 77.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.6ms
# Speed: 1.9ms preprocess, 76.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.3ms
# Speed: 1.7ms preprocess, 77.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.4ms
# Speed: 1.9ms preprocess, 76.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.2ms
# Speed: 2.5ms preprocess, 80.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.8ms
# Speed: 2.0ms preprocess, 79.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.1ms
# Speed: 1.9ms preprocess, 76.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.5ms
# Speed: 1.8ms preprocess, 77.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.8ms
# Speed: 2.0ms preprocess, 78.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.3ms
# Speed: 1.6ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.2ms
# Speed: 2.1ms preprocess, 79.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.7ms
# Speed: 2.5ms preprocess, 76.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 82.2ms
# Speed: 1.7ms preprocess, 82.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 118.3ms
# Speed: 8.7ms preprocess, 118.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.4ms
# Speed: 1.7ms preprocess, 77.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.8ms
# Speed: 2.3ms preprocess, 80.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.5ms
# Speed: 1.8ms preprocess, 78.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.6ms
# Speed: 2.2ms preprocess, 76.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.7ms
# Speed: 1.9ms preprocess, 77.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.6ms
# Speed: 1.9ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.9ms
# Speed: 1.8ms preprocess, 76.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.4ms
# Speed: 1.8ms preprocess, 76.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.5ms
# Speed: 2.4ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.1ms
# Speed: 2.1ms preprocess, 75.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.3ms
# Speed: 2.3ms preprocess, 78.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.9ms
# Speed: 1.8ms preprocess, 78.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 71.3ms
# Speed: 1.7ms preprocess, 71.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.9ms
# Speed: 1.7ms preprocess, 76.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.4ms
# Speed: 1.8ms preprocess, 79.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.1ms
# Speed: 1.9ms preprocess, 80.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.7ms
# Speed: 1.6ms preprocess, 77.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 76.1ms
# Speed: 1.7ms preprocess, 76.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.7ms
# Speed: 1.7ms preprocess, 79.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.4ms
# Speed: 1.7ms preprocess, 78.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.0ms
# Speed: 1.7ms preprocess, 80.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.7ms
# Speed: 1.7ms preprocess, 75.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 77.2ms
# Speed: 1.7ms preprocess, 77.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 83.6ms
# Speed: 2.4ms preprocess, 83.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 75.3ms
# Speed: 1.8ms preprocess, 75.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.3ms
# Speed: 1.9ms preprocess, 80.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.2ms
# Speed: 2.1ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.5ms
# Speed: 1.8ms preprocess, 78.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 80.3ms
# Speed: 1.6ms preprocess, 80.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cow, 78.3ms
# Speed: 1.8ms preprocess, 78.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
